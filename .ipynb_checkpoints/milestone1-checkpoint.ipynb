# %% [markdown]
# # Milestone 1

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import altair as alt

# %% [markdown]
# ## Read the data

# %%
url = 'https://raw.githubusercontent.com/luckyberen/DSCI320_Project/main/spotify_tracks.csv'
data = pd.read_csv(url)
data.head()
# Out:
#                  track_id     track_name  \
# 0  71ehTADpxs85ULrZgSEKCy   Almost Lover
# 1  2fPb58e6f8KxejYDCaARwS  Say Something
# 2  6Vc5wAMmXdKIAM7WUoEb7N  Say Something
# 3  7xLhousIHDxoGgeJNhO4Ye  Say Something
# 4  0jJqIi0uMG8IhGlLx7U85J   Already Home
#
#                                           album_name           artist_1  \
# 0                                One Cell In The Sea      A Fine Frenzy
# 1                        Is There Anybody Out There?  A Great Big World
# 2                        Is There Anybody Out There?  A Great Big World
# 3  Is There Anybody Out There? - Track by Track C...  A Great Big World
# 4  Is There Anybody Out There? - Track by Track C...  A Great Big World
#
#              artist_2 artist_3 artist_4 track_genre_1 track_genre_2  \
# 0                 NaN      NaN      NaN      acoustic           NaN
# 1                 NaN      NaN      NaN      acoustic         piano
# 2  Christina Aguilera      NaN      NaN      acoustic         piano
# ...

# %% [markdown]
# ## Summary of each variable

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89741 entries, 0 to 89740
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          89741 non-null  object
#  1   track_name        89740 non-null  object
#  2   album_name        89740 non-null  object
#  3   artist_1          89740 non-null  object
#  4   artist_2          22584 non-null  object
#  5   artist_3          6784 non-null   object
#  6   artist_4          2124 non-null   object
#  7   track_genre_1     89741 non-null  object
#  8   track_genre_2     16641 non-null  object
#  9   track_genre_3     4929 non-null   object
#  10  track_genre_4     1945 non-null   object
#  11  track_genre_5     573 non-null    object
#  12  explicit          89741 non-null  bool
#  13  mode              89741 non-null  object
#  14  key               89741 non-null  object
#  15  time_signature    89741 non-null  int64
# ...

# %%
data.describe()
# Out:
#        time_signature         tempo    duartion_s    popularity  danceability  \
# count    89741.000000  89741.000000  89741.000000  89741.000000  89741.000000
# mean         3.897427    122.058304    229.142024     33.198750      0.562166
# std          0.453435     30.117515    112.947758     20.581255      0.176691
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%          4.000000     99.260000    173.040000     19.000000      0.450000
# 50%          4.000000    122.010000    213.290000     33.000000      0.576000
# 75%          4.000000    140.080000    264.290000     49.000000      0.692000
# max          5.000000    243.370000   5237.300000    100.000000      0.985000
#
#            loudness   speechiness  acousticness  instrumentalness  \
# count  89741.000000  89741.000000  89741.000000      89741.000000
# mean      -8.499004      0.087442      0.328289          0.173413
# std        5.221490      0.113277      0.338321          0.323848
# ...

# %% [markdown]
# ## Visualizations of variables
#
# ### Nominal variables

# %%
alt.data_transformers.disable_max_rows()


plot_nominal = alt.Chart(data).mark_bar().encode(
    alt.X(alt.repeat('repeat'), type='nominal'),
    alt.Y('count()')
).properties(
  width=200,
  height=200
).repeat(
  data=data,
  repeat = ['explicit','mode','key', 'time_signature'],
  columns = 2
)


plot_nominal

# %% [markdown]
# ## Quantitative variables

# %%
plot_quantitative = alt.Chart(data).mark_bar().encode(
    alt.X(alt.repeat('repeat'), type='quantitative',bin=alt.BinParams(maxbins=30)),
    alt.Y('count()')
).properties(
  width=200,
  height=200
).repeat(
  data=data,
  repeat = ['tempo','duartion_s','popularity','danceability','loudness','speechiness','acousticness',
            'instrumentalness','liveness','energy','valence'],
  columns = 3
)
plot_quantitative

# %% [markdown]
# ## Bi-variable Visualizations

# %%
# plot_bivari = alt.Chart(data).mark_circle().encode(
#     alt.X(alt.repeat('row'),type='quantitative'),
#     alt.Y(alt.repeat('column'),type='quantitative'),
# ).properties(
#   width=200,
#   height=200
# ).repeat(
#   data=data,
#   row = ['tempo','danceability','loudness','popularity'],
#   column = ['popularity','loudness','danceability','tempo']
# )
# plot_bivari
